# %%
from requests_html import HTMLSession

url = 'https://news.google.com/rss/search?q=metaverse'

s = HTMLSession()

r = s.get(url)

for title in r.html.find('title'):
    print(title.text)
    print('-'*60)
# Out:
# "metaverse" - Google News
# ------------------------------------------------------------
# Walmart is quietly preparing to enter the metaverse - CNBC
# ------------------------------------------------------------
# How to Invest in the Metaverse - Coindesk
# ------------------------------------------------------------
# What the Metaverse has to do with Microsoft’s deal for Activision - Livemint
# ------------------------------------------------------------
# Here’s What a Metaverse Rave Is Like, I Guess - The Cut
# ------------------------------------------------------------
# Metaverse is pointless and VR headsets annoying, says the man who invented PlayStation - India Today
# ------------------------------------------------------------
# This Week In XR: Microsoft’s New Metaverse Play, Apple Delays, And Google’s AR Skunkworks - Forbes
# ------------------------------------------------------------
# AEKI Metaverse ($AEKI) Proves to be a Great Contender in - GlobeNewswire
# ------------------------------------------------------------
# A TN couple's wwwedding in the metaverse: What it will look like - The News Minute
# ------------------------------------------------------------
# Empire posts $18 million profit in 2021, led by gains in metaverse property, NFTs sales - Economic Times
# ------------------------------------------------------------
# Play and Earn: Is a decentralised gaming metaverse the future? - YourStory
# ------------------------------------------------------------
# South Korea Aims to Become One of the Biggest Metaverse Markets by 2026 - News18
# ------------------------------------------------------------
# This group of tech firms just signed up to a safer metaverse - MIT Technology Review
# ------------------------------------------------------------
# View: The Metaverse will bring great change, and even greater challenges - Economic Times
# ------------------------------------------------------------
# Cardano jumps on the metaverse bandwagon with Pavia — here’s everything you need to know about ADA’s entry int - Business Insider India
# ------------------------------------------------------------
# Kippo 2.0 pivots gamer dating app to the metaverse - VentureBeat
# ------------------------------------------------------------
# How Microsoft is charting its metaverse entry in India - BusinessLine
# ------------------------------------------------------------
# Google Finally Pushes Into Blockchain and Crypto — Is the Metaverse Next? - pymnts.com
# ------------------------------------------------------------
# Why Investors Are Paying Real Money For Virtual Land - TIME
# ------------------------------------------------------------
# ClassicDoge Releases Their Pet Metaverse and Ecosystem - GlobeNewswire
# ------------------------------------------------------------
# Comics ready for Metaverse with Amar Chitra Katha NFT, battle of Kurukshetra digital game - Fortune India
# ------------------------------------------------------------
# Daler Mehndi to present his first metaverse concert on Republic Day - United News of India
# ------------------------------------------------------------
# MetaGoons Raises $2M to Create the Premier Metaverse Lifestyle Brand and Announces Partnership with Team Pacquiao GG - Business Wire
# ------------------------------------------------------------
# Metaverse gets touch of reality at CES - Tech Xplore
# ------------------------------------------------------------
# Accounting firms scoop up virtual land in the metaverse - Livemint
# ------------------------------------------------------------
# University community leaps into the 'metaverse' - University of Miami: News@theU
# ------------------------------------------------------------
# Tencent Just Made Its Biggest Metaverse Move Yet - The Motley Fool
# ------------------------------------------------------------
# NFT-based metaverse company Animoca Brands raises $360 million - Reuters
# ------------------------------------------------------------
# Metaverse next, Microsoft is approaching carefully: CEO Satya Nadella - Moneycontrol
# ------------------------------------------------------------
# L'OFFICIEL to Launch a Fashion Collection in the Metaverse - AMTD Acquisition - L'Officiel
# ------------------------------------------------------------
# Miller Lite’s Super Bowl Ad Will Air Exclusively in the Metaverse - Adweek
# ------------------------------------------------------------
# UFC will host a fight in the Metaverse confirms Dana White - Techstory
# ------------------------------------------------------------
# Facebook, Instagram Jump Into NFTs, a Springboard to the Metaverse - pymnts.com
# ------------------------------------------------------------
# Chipmakers are set to be 'winners' as the metaverse takes off - CNBC
# ------------------------------------------------------------
# What India’s first Metaverse concert tells us about the future of virtual music events - The Indian Express
# ------------------------------------------------------------
# A new way to test user experiences in Facebook, Metaverse, and VR - IT Brief Australia
# ------------------------------------------------------------
# Chinese cities are piling into the metaverse - Quartz
# ------------------------------------------------------------
# These CES products are all-in on the metaverse - Popular Science
# ------------------------------------------------------------
# What will digital marketing look like in the metaverse? - Analytics India Magazine
# ------------------------------------------------------------
# Oculus Update Brings Apple's Magic Keyboard to the Metaverse - Gizmodo
# ------------------------------------------------------------
# Limoverse – A Star To Rise In The Metaverse Horizon Built On Blockchain - Outlook India
# ------------------------------------------------------------
# An Industry-Backed Group Thinks the Metaverse Can Avoid the Ills of Social Media. Here's How - TIME
# ------------------------------------------------------------
# Metaverse, The End Of Nuclear Power And Tested Valuations - Forbes
# ------------------------------------------------------------
# Second Life joins the metaverse discussion with the return of its founder — and some key patents - The Verge
# ------------------------------------------------------------
# Wax Dynasty Promotes Use Of The Kling Metaverse For The - GlobeNewswire
# ------------------------------------------------------------
# Apple Doesn't Want Anything to Do with Facebook's Metaverse. Why That's Very Bad News for Mark Zuckerberg - Inc.
# ------------------------------------------------------------
# Hashed And Icetea Labs Join Forces Towards A Common Goal In - GlobeNewswire
# ------------------------------------------------------------
# MegaDoge Introduces a Metaverse Featuring Exciting Blockchain Mega Games - GlobeNewswire
# ------------------------------------------------------------
# Video: How Roblox is introducing brands to the metaverse - AdAge.com
# ------------------------------------------------------------
# H&M has not opened a virtual cloth store in metaverse, video is just a concept - India Today
# ------------------------------------------------------------
# ZTE's Smartphone Brand Red Magic to Explore Metaverse Field - Pandaily
# ------------------------------------------------------------
# The Metaverse’s Dark Side: Here Come Harassment and Assaults - The New York Times
# ------------------------------------------------------------
# Apple's $2,000 VR/AR Headset to take on FB, Google in Metaverse - TheStreet
# ------------------------------------------------------------
# Metaverse startup Cyber raises $6.7 million from big name NFT investors - The Block Crypto
# ------------------------------------------------------------
# GamesBeat Summit: Into the Metaverse 2’s awesome agenda - VentureBeat
# ------------------------------------------------------------
# Elon Musk mocks ‘Metaverse’ idea, says nobody wants a screen strapped to their face - The Indian Express
# ------------------------------------------------------------
# From metaverse to LEO satellites, these factors will connect organisations in 2022 - ITP.net
# ------------------------------------------------------------
# adidas Originals and Prada Announce a First-of-its-Kind Open-Metaverse & User-generated NFT Project - adidas
# ------------------------------------------------------------
# Samsung takes a stab at its own immersive metaverse store - VentureBeat
# ------------------------------------------------------------
# Mars4 Metaverse NFT Sale Raises Over $250K in a Day: The World's First Virtual Mars NFTs Are Selling Rapidly – Sponsored Bitcoin News - Bitcoin News
# ------------------------------------------------------------
# Facebook's metaverse is its best PR campaign ever - Quartz
# ------------------------------------------------------------
# The cheapest real estate on popular metaverse platforms is already selling for more than $13,000 - Fortune
# ------------------------------------------------------------
# Square Enix President Yosuke Matsuda Says NFT, Metaverse, and Blockchain Are Here to Stay - Gadgets 360
# ------------------------------------------------------------
# Metaverse firm Ikonz sets eyes on a big slice of Indian NFT business - Economic Times
# ------------------------------------------------------------
# Hyundai wants to bring Mars to the metaverse so you don’t have to go there - Business Insider India
# ------------------------------------------------------------
# NFT protocol Metaplex raises $46M to expand gaming and metaverse applications - Cointelegraph
# ------------------------------------------------------------
# Ralph Lauren CEO says metaverse is way to tap into younger generation of shoppers - CNBC
# ------------------------------------------------------------
# Brooklyn Nets stake claim in metaverse with 'Netaverse' virtual realm - Markets Insider
# ------------------------------------------------------------
# Startup To Host Psychedelic Trips In The Metaverse - Forbes
# ------------------------------------------------------------
# London's Queen Mary students receive first lecture in the metaverse - City A.M.
# ------------------------------------------------------------
# Valiant Goes All In On NFT And Metaverse Web 3.0 - Maybe Comics Too? - Bleeding Cool News
# ------------------------------------------------------------
# Australian Open Partners Decentraland For Official Grand Slam In Metaverse | Bitcoinist.com - Bitcoinist
# ------------------------------------------------------------
# To the Moon: Lamborghini enters metaverse with 3D printed Space Key NFT - 3D Printing Industry
# ------------------------------------------------------------
# Virtual Real Estate NFT | Predecessor Of Metaverse - Finextra
# ------------------------------------------------------------
# Storyboard 18 - Metaverse: India will just not benefit from it, it will play a significant role in building it, says Meta's Ajit Mohan - Forbes India
# ------------------------------------------------------------
# How GAIMIN Is Supporting Metaverse and Web 3.0 Ecosystems – Sponsored Bitcoin News - Bitcoin News
# ------------------------------------------------------------
# How metaverse will finally help make sense of smart glasses - BGR India
# ------------------------------------------------------------
# Crypto Gamer the first-of-its-kind gaming platform in the metaverse announces the ILO Presale on 02 February 2022 - GlobeNewswire
# ------------------------------------------------------------
# How the metaverse, blockchain and NFTs are radically changing entertainment - TechRepublic
# ------------------------------------------------------------
# Gen Z investors shift focus from 'meme-stocks' to the 'metaverse,' report shows - Reuters
# ------------------------------------------------------------
# Tata Elxsi preps up for the metaverse - ETCIO.com
# ------------------------------------------------------------
# Why Digital India is a pioneer in the metaverse - The New Indian Express
# ------------------------------------------------------------
# ONE Sotheby’s Is Selling The First Real-World Home Through The Metaverse Using NFT Technology - Forbes
# ------------------------------------------------------------
# The Metaverse Offers Much Potential For Terrorists and Extremists - Defense One
# ------------------------------------------------------------
# Football’s future is in the metaverse - Financial Times
# ------------------------------------------------------------
# Movies and shows about the metaverse you can watch this Christmas - CNBCTV18
# ------------------------------------------------------------
# Nvidia embraces the metaverse with new software, marketplace deals - Reuters
# ------------------------------------------------------------
# Crypto year at a glance: Ethreum outperformed in 2021, Metaverse is new DeFi - Economic Times
# ------------------------------------------------------------
# Metapunks Announces NFT Metaverse Avatars Public Sale - GlobeNewswire
# ------------------------------------------------------------
# Disney patents metaverse technology for theme parks - Business Insider
# ------------------------------------------------------------
# Sportswear brand ASRV launches NFT collection in retail metaverse play - Markets Insider
# ------------------------------------------------------------
# Turkish ruling party holds meeting in metaverse, talks crypto regulation - Cointelegraph
# ------------------------------------------------------------
# Why Every 3D Designer / Architect Can Benefit From the Creator Economy in the Metaverse - ArchDaily
# ------------------------------------------------------------
# Binance.US Is Building an Office in the Solana Metaverse - CoinDesk
# ------------------------------------------------------------
# SPACE secures $7M in funding for arts and commerce virtual projects - VentureBeat
# ------------------------------------------------------------
# Creator who worked with Beyonce wants 'a metaverse your grandmother can understand' - Yahoo Finance
# ------------------------------------------------------------
# Qualcomm, Microsoft partner on metaverse chip for AR glasses - Reuters
# ------------------------------------------------------------
# Cisco Sees the Metaverse As a Path to Rebuild Webex's Market Share - Business Insider
# ------------------------------------------------------------
# New Year’s Eve Party Comes to the Metaverse as Times Square Building Owner Enters Decentraland - CoinDesk
# ------------------------------------------------------------
# Opinion | To Understand the Metaverse, Look to Video Games - The New York Times
# ------------------------------------------------------------
