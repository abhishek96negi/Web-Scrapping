# %% [markdown]
# # Webscrapping
#
# **Wesite Name** - skysports
#
# **Package Requirements**
#
#     pip install beautifulsoup4
#     pip install requests
#     pip install pandas
#
#
# **Website Image**
#
# ![image.png](attachment:image.png)
#
# **NOTES:-**
#
# Scrapping only Team Name and point.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = 'https://www.skysports.com/premier-league-table'

r = requests.get(url)

soup = BeautifulSoup(r.text, 'html.parser')

league_table = soup.find('table', class_='standing-table__table callfn')

league_table_point = []

for team in league_table.find_all('tbody'):
    rows =team.find_all('tr')
    for row in rows:
        p1_team = row.find('a', class_='standing-table__cell--name-link').text
        p1_points = row.find_all('td', class_='standing-table__cell')[9].text
        p1_data = {
            'Team': p1_team,
            'Points': p1_points
        }
        league_table_point.append(p1_data)

# %%
league_data_frame = pd.DataFrame(league_table_point)
league_data_frame
# Out:
#                         Team Points
# 0            Manchester City     53
# 1                    Chelsea     43
# 2                  Liverpool     42
# 3            West Ham United     37
# 4                    Arsenal     35
# 5          Tottenham Hotspur     33
# 6          Manchester United     31
# 7    Wolverhampton Wanderers     28
# 8   Brighton and Hove Albion     27
# 9             Leicester City     25
# 10               Southampton     24
# 11            Crystal Palace     23
# 12                 Brentford     23
# 13               Aston Villa     22
# 14                   Everton     19
# 15              Leeds United     19
# 16                   Watford     13
# 17                   Burnley     11
# 18          Newcastle United     11
# 19              Norwich City     10
