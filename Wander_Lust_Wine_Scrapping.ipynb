# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
product_list = []
headers = {
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36"
}

# Step 1 - Request
url = 'https://wanderlustwine.co.uk/buy-wine-online/'
r = requests.get(url, headers=headers)
soup = BeautifulSoup(r.content, 'lxml')

# %%
# Step 2 - Parse
products = soup.find_all('div', class_='product-details')
for product in products:
    product_name = product.find('h2', class_='woocommerce-loop-product__title').text.strip()
    product_link = product.find('h2', class_='woocommerce-loop-product__title').a['href']
    product_price = product.find('span', class_='woocommerce-Price-amount amount').text
    product_dict = {
        'product_name': product_name,
        'product_price':product_price,
        'product_link':product_link
    }
    product_list.append(product_dict)

# %%
# Step 3 - Output
df = pd.DataFrame(product_list)
df
# Out:
#                                          product_name product_price  \
# 0     Chateau de Miniere Organic Grape Juice (0% ABV)         £6.25
# 1                 Babylonstoren Sparkling Grape Juice         £7.50
# 2                                    4 Haz Dry Tokaji         £9.99
# 3                               Rouxvale Chenin Blanc         £9.99
# 4                                 £10 Gift Voucher(s)        £10.00
# 5                            Rouxvale Sauvignon Blanc        £10.25
# 6                                     Ariabal Verdejo        £10.25
# 7                             4 Haz Sparkling Furmint        £10.50
# 8                                     Rouxvale Merlot        £10.50
# 9                                 Rouxvale Chardonnay        £10.50
# 10                      Babylonstoren ‘Candide’ Blend        £10.75
# 11                                          JaJa Rose        £11.00
# 12                                     JaJa Sauvignon        £11.00
# 13                                         JaJa Syrah        £11.00
# 14                            JaJa Cabernet Sauvignon        £11.00
# 15                        Fontaine du Clos Chardonnay        £11.50
# 16                         Babylonstoren Chenin Blanc        £11.50
# 17                       Remhoogte First Light Chenin        £11.99
# 18                 Rouxvale Late Harvest Chenin Blanc        £11.99
# 19                                      Liberté Rouge        £12.00
# 20                                      Liberté Blanc        £12.00
# 21                              Liberté Provence Rose        £12.00
# 22                                     Certitude Rose        £12.00
# 23                           Rouxvale Shiraz Viognier        £12.00
# 24                      Chateau de Miniere Loire Rose        £12.25
# 25                              4 Haz Organic Furmint        £12.25
# 26                    Molmenti & Celot Cabernet Franc        £12.50
# 27                          Molmenti & Celot Friulano        £11.75
# 28                                       Pratsch Rose        £12.50
# 29                                     Pandra Verdejo        £12.50
# 30  Remhoogte ‘Free to Be’ Vine-Dried Riesling (37...        £12.50
# 31                              Kolonics Olaszrizling        £12.75
# 32                      Rouxvale Sparkling Chardonnay        £12.95
# 33                                      Dagon Clestar        £12.99
# 34                                     Dagon Har Rose        £12.99
# 35                           Molmenti & Celot Refosco        £12.99
# 36                            Heumann Kekfrankos Rose        £13.00
