# %%
import pandas as pd

# %%
df = pd.read_html('https://fastestlaps.com/tracks/le-mans-bugatti')
df
# Out:
# [      Rank                          Vehicle              Driver     Time  \
#  0      1.0             Yamaha YZR-M1 (2016)        Johann Zarco  1:31.18
#  1      2.0              Honda RC213V (2018)        Marc Marquez  1:31.29
#  2      3.0             Yamaha YZR-M1 (2020)    Fabio Quartararo  1:31.31
#  3      4.0                      Ducati GP18     Danilo Petrucci  1:31.38
#  4      5.0             Suzuki GSX-RR (2018)      Andrea Iannone  1:31.45
#  ..     ...                              ...                 ...      ...
#  228  229.0  C63 AMG Coupe Performance Pac..       Steve Stanton  2:07.00
#  229  230.0                Abarth 124 Spider             unknown  2:07.25
#  230  231.0                   Ford Fiesta ST             unknown  2:08.18
#  231  232.0            Alpine A110 S (Mk II)  Christophe Tinseau  2:09.94
#  232  233.0         Mazda MX-5 Grand Touring  Christophe Tinseau  2:10.69
#
#          PS / KG
#  0         - / -
#  1         - / -
#  2         - / -
# ...

# %%
df[0]
# Out:
#       Rank                          Vehicle              Driver     Time  \
# 0      1.0             Yamaha YZR-M1 (2016)        Johann Zarco  1:31.18
# 1      2.0              Honda RC213V (2018)        Marc Marquez  1:31.29
# 2      3.0             Yamaha YZR-M1 (2020)    Fabio Quartararo  1:31.31
# 3      4.0                      Ducati GP18     Danilo Petrucci  1:31.38
# 4      5.0             Suzuki GSX-RR (2018)      Andrea Iannone  1:31.45
# ..     ...                              ...                 ...      ...
# 228  229.0  C63 AMG Coupe Performance Pac..       Steve Stanton  2:07.00
# 229  230.0                Abarth 124 Spider             unknown  2:07.25
# 230  231.0                   Ford Fiesta ST             unknown  2:08.18
# 231  232.0            Alpine A110 S (Mk II)  Christophe Tinseau  2:09.94
# 232  233.0         Mazda MX-5 Grand Touring  Christophe Tinseau  2:10.69
#
#         PS / KG
# 0         - / -
# 1         - / -
# 2         - / -
# 3         - / -
# ...
